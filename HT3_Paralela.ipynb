# %%
# !ls /usr/local
# Out:
# bin    cuda	cuda-11.8  games	       include	lib64	   man	 share
# colab  cuda-11	etc	   _gcs_config_ops.so  lib	licensing  sbin  src

# %%
# !which nvcc
# Out:
# /usr/local/cuda/bin/nvcc

# %%
# !nvidia-smi
# Out:
# Tue Oct 31 01:19:27 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !nvcc -arch=sm_37 -gencode=arch=compute_37,code=sm_37 hello.cu -o hello
# Out:
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./hello
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world

# %%
# !nvcc -arch=sm_37 -gencode=arch=compute_37,code=sm_37 hello.cu -o hello2
# Out:
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./hello2
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world

# %%
# !nvidia-smi
# Out:
# Tue Oct 31 01:19:32 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    25W /  70W |      0MiB / 15360MiB |      6%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# https://developer.nvidia.com/cuda-gpus
# En este link se obtuvo el CC en base a Tesla T4

# %%
# !nvcc -arch=sm_37 -gencode=arch=compute_37,code=sm_37 hello.cu -o hello3
# Out:
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./hello3
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world

# %%
# !nvcc -arch=sm_37 -gencode=arch=compute_37,code=sm_37 hello2.cu -o hello2A
# Out:
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./hello2A
# Out:
# Hello world from 140
# Hello world from 141
# Hello world from 142
# Hello world from 143
# Hello world from 144
# Hello world from 145
# Hello world from 146
# Hello world from 147
# Hello world from 148
# Hello world from 149
# Hello world from 40
# Hello world from 41
# Hello world from 42
# Hello world from 43
# Hello world from 44
# Hello world from 45
# Hello world from 46
# Hello world from 47
# Hello world from 48
# Hello world from 49
# Hello world from 190
# Hello world from 191
# Hello world from 192
# Hello world from 193
# Hello world from 194
# Hello world from 195
# Hello world from 196
# Hello world from 197
# Hello world from 198
# Hello world from 199
# Hello world from 90
# Hello world from 91
# Hello world from 92
# Hello world from 93
# Hello world from 94
# Hello world from 95
# Hello world from 96
# Hello world from 97
# Hello world from 98
# Hello world from 99
# Hello world from 110
# Hello world from 111
# Hello world from 112
# Hello world from 113
# ...

# %%
# !nvcc -arch=sm_37 -gencode=arch=compute_37,code=sm_37 hello2.cu -o hello2B
# Out:
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./hello2B
# Out:
# Hello world from 896 by Christopher García 20541
# Hello world from 897 by Christopher García 20541
# Hello world from 898 by Christopher García 20541
# Hello world from 899 by Christopher García 20541
# Hello world from 900 by Christopher García 20541
# Hello world from 901 by Christopher García 20541
# Hello world from 902 by Christopher García 20541
# Hello world from 903 by Christopher García 20541
# Hello world from 904 by Christopher García 20541
# Hello world from 905 by Christopher García 20541
# Hello world from 906 by Christopher García 20541
# Hello world from 907 by Christopher García 20541
# Hello world from 908 by Christopher García 20541
# Hello world from 909 by Christopher García 20541
# Hello world from 910 by Christopher García 20541
# Hello world from 911 by Christopher García 20541
# Hello world from 912 by Christopher García 20541
# Hello world from 913 by Christopher García 20541
# Hello world from 914 by Christopher García 20541
# ...

# %%
# !nvcc -arch=sm_37 -gencode=arch=compute_37,code=sm_37 hello2_1.cu -o hello2C
# Out:
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./hello2C
# Out:
# Max Threads Per Block (x): 1024
# Max Threads Per Block (y): 1024
# Max Threads Per Block (z): 64
# Max Blocks Per Grid (x): 2147483647
# Max Blocks Per Grid (y): 65535
# Max Blocks Per Grid (z): 65535
# Hello world from 100351 by Christopher García 20541
